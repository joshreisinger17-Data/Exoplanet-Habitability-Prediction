# %% [markdown]
# # Exoplanet Habitability Analysis Using Stellar and Planetary Characteristics
# This project investigates the relationships between stellar and planetary characteristics and exoplanet habitability. The project will be using publicly available datasets from the NASA Archive and exoplanet datasets, where the analysis will identify the variables most strongly associated with the Earth Similarity Index (ESI) values. A machine learning classification model will be developed to predict whether an exoplanet is habitable based on the stellar and planetary characteristics.
#
# ## Research Question
# What stellar and planetary characteristics are most strongly associated with exoplanet habitability as measured by Earth Similarity Index (ESI)?
#
# ## Project Objective
# Analyze stellar and exoplanet datasets to identify characteristics most associated with habitability.
#
# ## Target Variables
# - Earth Similarity Index (ESI), used to classify planets as habitable or non-habitable.
#
# ## Planetary Features
# - Planet name
# - Planet Radius (Earth Radii)
# - Orbital Period (days)
#
# ## Stellar Features
# - Host Star
# - Stellar Radius (Solar Radii)
# - Stellar Temperature (K)
# - Stellar Mass (Solar Masses)
# - Stellar Metallicity
#
# ## Habitability Features
# - Planet Type
# - Planet Mass (Earth Masses)
# - Stellar Flux (Earth Flux)
# - Surface Temperature (K)
# - Distance (Light Years)
# - Planet Years (Gigayears)
# - Earth Similarity Index
#
# ## Project Approach
# Following data collection and preparation this project will be used Exploratory Data Analysis to identify trends and relationships among stellar and planetary characteristics. The machine learning classification model will then be developed to predict planet habitability based on these features. The model performance will be evaluated using classification metrics, and feature importance will identify the characteristics that contribute most to habitability predictions.

# %% [markdown]
# ## Data Acquisition
# The project uses multiple publicly available stellar and exoplanet datasets from the NASA Archive and Kaggle. The datasets contain the relevant stellar and planetary features, and will be combined and prepared for exploratory data analysis, as well as the machine learning modeling.

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Dataset 1: Planetary Systems
# This dataset is acquired from the NASA Archives and contains the characteristics of the exoplanets and their host star. The dataset provides the relevant information about the exoplanets and the stars they orbit.

# %%
# Load the dataset
df_stellar_planets = pd.read_csv('data/planetary_systems.csv', sep=",", comment="#")
# Confirm data is loaded correctly
df_stellar_planets.head()
# Out:
#     pl_name hostname  default_flag  \
# 0  11 Com b   11 Com             1
# 1  11 Com b   11 Com             0
# 2  11 Com b   11 Com             0
# 3  11 UMi b   11 UMi             0
# 4  11 UMi b   11 UMi             0
#
#                                           pl_refname  pl_orbper  \
# 0  <a refstr=TENG_ET_AL_2023 href=https://ui.adsa...     323.21
# 1  <a refstr=KUNITOMO_ET_AL__2011 href=https://ui...        NaN
# 2  <a refstr=LIU_ET_AL__2008 href=https://ui.adsa...     326.03
# 3  <a refstr=KUNITOMO_ET_AL__2011 href=https://ui...        NaN
# 4  <a refstr=DOLLINGER_ET_AL__2009 href=https://u...     516.22
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  \
# 0           0.06          -0.05           0.0       1.178            0.00
# 1            NaN            NaN           NaN       1.210            0.06
# 2           0.32          -0.32           0.0       1.290            0.05
# ...

# %% [markdown]
# ### Dataset 2: Habitable Exoplanets
# This dataset contains potentially habitable exoplanets and includes some of the key characteristics and importantly contains the target variable, the Earth Similarity Index (ESI). The dataset will be used to combine with dataset one to analyze the characteristics to identify which variables are most strongly associated with habitable exoplanets.

# %%
# Load the dataset
df_habitable_planets = pd.read_csv('data/hwc_table_all.csv')
# Confirm data is loaded correctly
df_habitable_planets.head()
# Out:
#         Name                Type Detection Method  Mass<br>(M<sub>E</sub>)  \
# 0  TOI-904 c  M Warm Superterran          Transit                    5.340
# 1  TOI-700 e       M Warm Terran          Transit                    0.818
# 2  TOI-700 d       M Warm Terran          Transit                    1.250
# 3   GJ 357 d  M Warm Superterran  Radial Velocity                    6.100
# 4  GJ 3293 d  M Warm Superterran  Radial Velocity                    7.600
#
#    Radius<br>(R<sub>E</sub>)  Flux<br>(S<sub>E</sub>)  \
# 0                      2.167                 0.524434
# 1                      0.953                 1.278049
# 2                      1.073                 0.859827
# 3                      2.340                 0.382595
# 4                      2.670                 0.588593
#
#    <i>T<sub>surf</sub></i><br>(K)  Period<br>(days)  Distance<br>(ly)  \
# 0                      244.820750          83.99970        150.322365
# ...

# %% [markdown]
# # Data Understanding

# %%
# Check the shape of the dataset
df_stellar_planets.shape
# Out:
# (39876, 63)

# %%
# Check the data types and missing values
df_stellar_planets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39876 entries, 0 to 39875
# Data columns (total 63 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39876 non-null  str
#  1   hostname         39876 non-null  str
#  2   default_flag     39876 non-null  int64
#  3   pl_refname       39876 non-null  str
#  4   pl_orbper        36491 non-null  float64
#  5   pl_orbpererr1    34783 non-null  float64
#  6   pl_orbpererr2    34782 non-null  float64
#  7   pl_orbperlim     36491 non-null  float64
#  8   pl_orbsmax       22243 non-null  float64
#  9   pl_orbsmaxerr1   7769 non-null   float64
#  10  pl_orbsmaxerr2   7768 non-null   float64
#  11  pl_orbsmaxlim    25030 non-null  float64
#  12  pl_rade          27502 non-null  float64
#  13  pl_radeerr1      26757 non-null  float64
#  14  pl_radeerr2      26757 non-null  float64
#  15  pl_radelim       30248 non-null  float64
#  16  pl_radj          27502 non-null  float64
# ...

# %%
# Generate summary statistics
df_stellar_planets.describe()
# Out:
#        default_flag     pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  \
# count  39876.000000  3.649100e+04   3.478300e+04   3.478200e+04  36491.000000
# mean       0.157764  1.199261e+04   1.386947e+04  -3.268969e+03     -0.000247
# std        0.364524  2.105646e+06   2.520262e+06   5.374310e+05      0.020273
# min        0.000000  9.070629e-02   0.000000e+00  -1.000000e+08     -1.000000
# 25%        0.000000  4.366325e+00   8.060000e-06  -2.000000e-04      0.000000
# 50%        0.000000  1.029678e+01   3.818000e-05  -3.824000e-05      0.000000
# 75%        0.000000  2.635766e+01   2.000000e-04  -8.078725e-06      0.000000
# max        1.000000  4.020000e+08   4.700000e+08   0.000000e+00      1.000000
#
#          pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  pl_orbsmaxlim  \
# count  22243.000000     7769.000000     7768.000000   25030.000000
# mean       4.760748        1.041064       -0.700819      -0.000160
# ...

# %%
# Count missing values in each column
df_stellar_planets.isnull().sum()
# Out:
# pl_name             0
# hostname            0
# default_flag        0
# pl_refname          0
# pl_orbper        3385
#                 ...
# st_lum          30088
# st_lumerr1      35000
# st_lumerr2      35055
# st_lumlim       30088
# sy_refname         37
# Length: 63, dtype: int64

# %% [markdown]
# ## Dataset 1 Findings
# The planetary systems dataset contains 39,876 rows and 63 columns describing planetary and stellar characteristic. The dataset contains categorical and numerical features where several of the variables have missing values. The missing values will be addressed during data cleaning. The summary statistics show a wide range of values across planetary and stellar variables, suggesting a large variation among the exoplanet systems.

# %%
# Check the shape of the dataset
df_habitable_planets.shape
# Out:
# (70, 11)

# %%
# Check the data types and missing values
df_habitable_planets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Name                            70 non-null     str
#  1   Type                            70 non-null     str
#  2   Detection Method                70 non-null     str
#  3   Mass<br>(M<sub>E</sub>)         70 non-null     float64
#  4   Radius<br>(R<sub>E</sub>)       70 non-null     float64
#  5   Flux<br>(S<sub>E</sub>)         70 non-null     float64
#  6   <i>T<sub>surf</sub></i><br>(K)  70 non-null     float64
#  7   Period<br>(days)                70 non-null     float64
#  8   Distance<br>(ly)                70 non-null     float64
#  9   Age<br>(Gy)                     49 non-null     float64
#  10  ESI                             70 non-null     float64
# dtypes: float64(8), str(3)
# memory usage: 6.1 KB

# %%
# Generate summary statistics
df_habitable_planets.describe()
# Out:
#        Mass<br>(M<sub>E</sub>)  Radius<br>(R<sub>E</sub>)  \
# count                70.000000                  70.000000
# mean                  5.288748                   1.770514
# std                   6.247585                   0.557559
# min                   0.388000                   0.788000
# 25%                   2.202500                   1.302500
# 50%                   4.060000                   1.780000
# 75%                   5.680000                   2.198500
# max                  36.000000                   3.030000
#
#        Flux<br>(S<sub>E</sub>)  <i>T<sub>surf</sub></i><br>(K)  \
# count                70.000000                       70.000000
# mean                  0.866255                      269.496160
# std                   0.392595                       34.614972
# min                   0.252321                      198.928456
# 25%                   0.534217                      245.259471
# ...

# %%
# Count missing values in each column
df_habitable_planets.isnull().sum()
# Out:
# Name                               0
# Type                               0
# Detection Method                   0
# Mass<br>(M<sub>E</sub>)            0
# Radius<br>(R<sub>E</sub>)          0
# Flux<br>(S<sub>E</sub>)            0
# <i>T<sub>surf</sub></i><br>(K)     0
# Period<br>(days)                   0
# Distance<br>(ly)                   0
# Age<br>(Gy)                       21
# ESI                                0
# dtype: int64

# %% [markdown]
# ## Dataset 2 Findings
# The habitable exoplanets dataset contains 70 rows and 11 columns related to the habitable exoplanets. All variables are complete except for the *Age* variable, which contains 21 missing values. The dataset contains the target variable, the Earth Similarity Index (ESI), and provides habitability measurements that will be merged with the planetary systems dataset for further analysis.

# %% [markdown]
# # Data Preparation / Data Cleaning

# %%
# Create dataset copies for cleaning
stellar_planets_clean = df_stellar_planets.copy()
habitable_planets_clean = df_habitable_planets.copy()

# %% [markdown]
# ## Dataset 1 Cleaning

# %%
# Select relevant features for analysis
stellar_planets_clean = stellar_planets_clean[
    [
        'pl_name', 
        'hostname', 
        'pl_orbper', 
        'pl_orbsmax', 
        'pl_rade',
        'pl_bmasse', 
        'pl_orbeccen', 
        'pl_insol', 
        'pl_eqt', 
        'st_spectype', 
        'st_teff', 
        'st_rad', 
        'st_mass', 
        'st_met', 
        'st_lum'
   ]
]

# Verify selected features
stellar_planets_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39876 entries, 0 to 39875
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pl_name      39876 non-null  str
#  1   hostname     39876 non-null  str
#  2   pl_orbper    36491 non-null  float64
#  3   pl_orbsmax   22243 non-null  float64
#  4   pl_rade      27502 non-null  float64
#  5   pl_bmasse    7403 non-null   float64
#  6   pl_orbeccen  18949 non-null  float64
#  7   pl_insol     17331 non-null  float64
#  8   pl_eqt       17501 non-null  float64
#  9   st_spectype  3055 non-null   str
#  10  st_teff      36257 non-null  float64
#  11  st_rad       36467 non-null  float64
#  12  st_mass      33404 non-null  float64
#  13  st_met       24978 non-null  float64
#  14  st_lum       9788 non-null   float64
# dtypes: float64(12), str(3)
# memory usage: 4.6 MB

# %%
# Check for duplicates
stellar_planets_clean.duplicated().sum()
# Out:
# np.int64(5483)

# %%
# Remove duplicates
stellar_planets_clean = stellar_planets_clean.drop_duplicates()

# Verify duplicates are removed
stellar_planets_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Evaluate Percentage of Missing Values
missing_values = stellar_planets_clean.isnull().sum()
missing_percentage = (missing_values / len(stellar_planets_clean)) * 100
missing_percentage
# Out:
# pl_name         0.000000
# hostname        0.000000
# pl_orbper       9.554270
# pl_orbsmax     51.184834
# pl_rade        35.649696
# pl_bmasse      78.728230
# pl_orbeccen    60.518129
# pl_insol       65.219667
# pl_eqt         64.734103
# st_spectype    91.134824
# st_teff        10.228826
# st_rad          9.612421
# st_mass        18.762539
# st_met         42.997122
# st_lum         71.561073
# dtype: float64

# %%
# Drop columns with more than 50% missing values
stellar_planets_clean = stellar_planets_clean.dropna(thresh=len(stellar_planets_clean) * 0.5, axis=1)

# Verify columns are dropped
stellar_planets_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 34393 entries, 0 to 39875
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pl_name    34393 non-null  str
#  1   hostname   34393 non-null  str
#  2   pl_orbper  31107 non-null  float64
#  3   pl_rade    22132 non-null  float64
#  4   st_teff    30875 non-null  float64
#  5   st_rad     31087 non-null  float64
#  6   st_mass    27940 non-null  float64
#  7   st_met     19605 non-null  float64
# dtypes: float64(6), str(2)
# memory usage: 2.4 MB

# %%
# Fill missing values with median for numerical columns
numerical_cols = stellar_planets_clean.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    stellar_planets_clean[col] = stellar_planets_clean[col].fillna(stellar_planets_clean[col].median())

# Verify missing values are filled
stellar_planets_clean.isnull().sum()
# Out:
# pl_name      0
# hostname     0
# pl_orbper    0
# pl_rade      0
# st_teff      0
# st_rad       0
# st_mass      0
# st_met       0
# dtype: int64

# %%
# Rename columns for clarity
stellar_planets_clean = stellar_planets_clean.rename(columns={
    'pl_name': 'planet_name',
    'hostname': 'host_star',
    'pl_orbper': 'orbital_period_days',
    'pl_rade': 'planet_radius_earth',
    'st_teff': 'star_temperature_K',
    'st_rad': 'stellar_radius_solar',
    'st_mass': 'stellar_mass_solar_masses',
    'st_met': 'stellar_metallicity'
})

# Verify column names are updated
stellar_planets_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 34393 entries, 0 to 39875
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   planet_name                34393 non-null  str
#  1   host_star                  34393 non-null  str
#  2   orbital_period_days        34393 non-null  float64
#  3   planet_radius_earth        34393 non-null  float64
#  4   star_temperature_K         34393 non-null  float64
#  5   stellar_radius_solar       34393 non-null  float64
#  6   stellar_mass_solar_masses  34393 non-null  float64
#  7   stellar_metallicity        34393 non-null  float64
# dtypes: float64(6), str(2)
# memory usage: 2.4 MB

# %% [markdown]
# ### Dataset 1 Cleaning Summary
# The planetary system dataset was cleaned to improve quality and ensure consistency for analysis. First, only the most relevant characteristics were selected for analysis, reducing the dataset to specific stellar and planet characteristics. Duplicated entries were identified, and 5,483 duplicates were removed from the dataset. The reduction in the duplicates improves reliability of analysis. Missing values were identified next. Features with more than 50% missing values were removed because the significant proportion of missing values will negatively impact model performance and reduce reliability of the model and analysis. Next, to preserve as much data as possible, missing numerical values were filled using the median of each respective feature. Median imputation was used because it is less sensitive to outliers than mean imputation, and helps preserve the distribution of the data. Finally, after cleaning the dataset 8 features and 34,393 observations remain, each of the remaining features were renamed to improve clarity. The names are understandable and include metrics for the specified measurement of the feature. The dataset is now ready for analysis and machine learning modeling.

# %% [markdown]
# ## Dataset 2 Cleaning

# %%
# Select relevant features for analysis
habitable_planets_clean = habitable_planets_clean[
    [
        'Name',
        'Type',
        'Mass<br>(M<sub>E</sub>)',
        'Radius<br>(R<sub>E</sub>)',
        'Flux<br>(S<sub>E</sub>)',
        '<i>T<sub>surf</sub></i><br>(K)',
        'Period<br>(days)',
        'Distance<br>(ly)',
        'Age<br>(Gy)',
        'ESI'
    ]
]

# %%
# Check for duplicates
habitable_planets_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Evaluate Percentage of missing values, only Age has missing values from data understanding above
missing_percentage = (habitable_planets_clean.isnull().sum() / len(habitable_planets_clean)) * 100
missing_percentage
# Out:
# Name                               0.0
# Type                               0.0
# Mass<br>(M<sub>E</sub>)            0.0
# Radius<br>(R<sub>E</sub>)          0.0
# Flux<br>(S<sub>E</sub>)            0.0
# <i>T<sub>surf</sub></i><br>(K)     0.0
# Period<br>(days)                   0.0
# Distance<br>(ly)                   0.0
# Age<br>(Gy)                       30.0
# ESI                                0.0
# dtype: float64

# %%
# Fill missing values in Age column with median
habitable_planets_clean['Age<br>(Gy)'] = habitable_planets_clean['Age<br>(Gy)'].fillna(habitable_planets_clean['Age<br>(Gy)'].median())

# Verify missing values are filled
habitable_planets_clean.isnull().sum()
# Out:
# Name                              0
# Type                              0
# Mass<br>(M<sub>E</sub>)           0
# Radius<br>(R<sub>E</sub>)         0
# Flux<br>(S<sub>E</sub>)           0
# <i>T<sub>surf</sub></i><br>(K)    0
# Period<br>(days)                  0
# Distance<br>(ly)                  0
# Age<br>(Gy)                       0
# ESI                               0
# dtype: int64

# %%
# Rename columns for clarity
habitable_planets_clean = habitable_planets_clean.rename(columns={
    'Name': 'planet_name',
    'Type': 'planet_type',
    'Mass<br>(M<sub>E</sub>)': 'planet_mass_earth',
    'Radius<br>(R<sub>E</sub>)': 'planet_radius_earth',
    'Flux<br>(S<sub>E</sub>)': 'stellar_flux_earth',
    '<i>T<sub>surf</sub></i><br>(K)': 'surface_temperature_K',
    'Period<br>(days)': 'orbital_period_days',
    'Distance<br>(ly)': 'distance_light_years',
    'Age<br>(Gy)': 'planet_age_gigayears',
    'ESI': 'earth_similarity_index'
})

# Verify column names are updated
habitable_planets_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   planet_name             70 non-null     str
#  1   planet_type             70 non-null     str
#  2   planet_mass_earth       70 non-null     float64
#  3   planet_radius_earth     70 non-null     float64
#  4   stellar_flux_earth      70 non-null     float64
#  5   surface_temperature_K   70 non-null     float64
#  6   orbital_period_days     70 non-null     float64
#  7   distance_light_years    70 non-null     float64
#  8   planet_age_gigayears    70 non-null     float64
#  9   earth_similarity_index  70 non-null     float64
# dtypes: float64(8), str(2)
# memory usage: 5.6 KB

# %% [markdown]
# ### Dataset 2 Cleaning Summary
# The habitable exoplanets dataset was cleaned to improve quality and prepare it for analysis. First, the most relevant planetary features were selected with the target variable, the Earth Similarity Index (ESI). The dataset was checked for duplicates and none were identified. Next, only the planet age contained missing values, where approximately 30% of the observations were missing. Tp preserve the data, the missing age values were filled using the median age of the feature. Similarly, median imputation was selected because it is less sensitive to outliers tha mean imputation and helps preserve the overall distribution of the data. Lastly, the column names were renamed to improve clarity and readable. The feature names that matched dataset names, were named correspondingly, so the datasets are merged accurately. The cleaned dataset contains 10 features and 70 observations, and is now ready for analysis and machine learning modeling.

# %% [markdown]
# # Merge the Cleaned Datasets

# %%
# Merge the two datasets on planet_name
merged_planets = pd.merge(stellar_planets_clean, habitable_planets_clean, on='planet_name', how='inner')

# Verify merged dataset
merged_planets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   planet_name                324 non-null    str
#  1   host_star                  324 non-null    str
#  2   orbital_period_days_x      324 non-null    float64
#  3   planet_radius_earth_x      324 non-null    float64
#  4   star_temperature_K         324 non-null    float64
#  5   stellar_radius_solar       324 non-null    float64
#  6   stellar_mass_solar_masses  324 non-null    float64
#  7   stellar_metallicity        324 non-null    float64
#  8   planet_type                324 non-null    str
#  9   planet_mass_earth          324 non-null    float64
#  10  planet_radius_earth_y      324 non-null    float64
#  11  stellar_flux_earth         324 non-null    float64
#  12  surface_temperature_K      324 non-null    float64
# ...

# %%
# Check planet names in merged dataset
merged_planets['planet_name'].nunique()
# Out:
# 70

# %%
# Count how many radius values are the same
(merged_planets['planet_radius_earth_x'] == merged_planets['planet_radius_earth_y']).sum()
# Out:
# np.int64(43)

# %%
# Statistically compare the two radius columns
merged_planets[['planet_radius_earth_x', 'planet_radius_earth_y']].describe()
# Out:
#        planet_radius_earth_x  planet_radius_earth_y
# count             324.000000             324.000000
# mean                2.198386               1.754235
# std                 2.703893               0.462463
# min                 0.530000               0.788000
# 25%                 1.597500               1.410000
# 50%                 2.208500               1.780000
# 75%                 2.370000               2.170000
# max                38.670000               3.030000

# %%
# Statistically compare the two orbital period columns
merged_planets[['orbital_period_days_x', 'orbital_period_days_y']].describe()
# Out:
#        orbital_period_days_x  orbital_period_days_y
# count             324.000000             324.000000
# mean               92.106996             101.525451
# std                88.305510              89.631206
# min                 4.049219               4.049219
# 25%                24.737080              32.939623
# 50%                56.056065              63.336270
# 75%               129.945770             140.252400
# max               384.847556             384.843000

# %%
# Check missing values in the merged dataset
merged_planets.isnull().sum()
# Out:
# planet_name                  0
# host_star                    0
# orbital_period_days_x        0
# planet_radius_earth_x        0
# star_temperature_K           0
# stellar_radius_solar         0
# stellar_mass_solar_masses    0
# stellar_metallicity          0
# planet_type                  0
# planet_mass_earth            0
# planet_radius_earth_y        0
# stellar_flux_earth           0
# surface_temperature_K        0
# orbital_period_days_y        0
# distance_light_years         0
# planet_age_gigayears         0
# earth_similarity_index       0
# dtype: int64

# %%
# Drop duplicate columns from the merged dataset
merged_planets = merged_planets.drop(columns=['orbital_period_days_x', 'planet_radius_earth_x'])

# Rename remaining columns for clarity
merged_planets = merged_planets.rename(columns={'orbital_period_days_y': 'orbital_period_days', 
                                                'planet_radius_earth_y': 'planet_radius_earth'})
# Verify final merged dataset
merged_planets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   planet_name                324 non-null    str
#  1   host_star                  324 non-null    str
#  2   star_temperature_K         324 non-null    float64
#  3   stellar_radius_solar       324 non-null    float64
#  4   stellar_mass_solar_masses  324 non-null    float64
#  5   stellar_metallicity        324 non-null    float64
#  6   planet_type                324 non-null    str
#  7   planet_mass_earth          324 non-null    float64
#  8   planet_radius_earth        324 non-null    float64
#  9   stellar_flux_earth         324 non-null    float64
#  10  surface_temperature_K      324 non-null    float64
#  11  orbital_period_days        324 non-null    float64
#  12  distance_light_years       324 non-null    float64
# ...

# %%
# Create merged dataframe
merged_planets.to_csv('data/merged_planets.csv', index=False)

# %% [markdown]
# ### Merge Summary
# The planetary systems and habitable planet datasets were merged on *planet_name*, resulting in 324 observations and 15 features. There were duplicated columns created during the merge, *orbital_period_days* and *planet_radius_earth* were examined then removed. The related columns for the habitable planet dataset were kept because they are directly associated with the Earth Similarity Index (ESI) and related to the habitable measurements for the analysis. The merged dataset does not contain missing values, and is now ready for further analysis.

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
## Statistical Examination
merged_planets.describe()
# Out:
#        star_temperature_K  stellar_radius_solar  stellar_mass_solar_masses  \
# count          324.000000            324.000000                 324.000000
# mean          4278.906667              0.613515                   0.623762
# std            919.529162              0.314817                   0.286900
# min           2520.000000              0.107000                   0.080200
# 25%           3525.000000              0.421000                   0.429000
# 50%           4141.000000              0.600000                   0.636818
# 75%           4931.750000              0.781000                   0.896250
# max           5906.000000              3.204000                   1.592000
#
#        stellar_metallicity  planet_mass_earth  planet_radius_earth  \
# count           324.000000         324.000000           324.000000
# mean             -0.077474           6.319910             1.754235
# std               0.171220           8.265157             0.462463
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Earth Similarity Index (ESI)

# %%
# Create Univariate Method
def univariate_analysis(df, column):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], bins=20, kde=True)
    plt.title(f'Univariate Analysis of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

    print(df[column].describe())

# %%
# Call Univariate method for Earth Similarity Index
univariate_analysis(merged_planets, 'earth_similarity_index')
# Out:
# count    324.000000
# mean       0.746048
# std        0.088520
# min        0.475466
# 25%        0.678714
# 50%        0.730737
# 75%        0.814264
# max        0.968362
# Name: earth_similarity_index, dtype: float64

# %% [markdown]
# The Earth Similarity Index (ESI) distribution is concentrated approximately in the range of 0.65 and 0.85, while peaking between 0.70 and 0.75. The histogram suggests that most planets for the dataset exhibit moderate to high similarity or Earth. Few planets show low values of ESI, while slightly more show higher values of ESI, which suggests a relatively consistent range of habitability characteristics.

# %% [markdown]
# ### Planet Radius

# %%
# Call Univariate method for Planet Radius
univariate_analysis(merged_planets, 'planet_radius_earth')
# Out:
# count    324.000000
# mean       1.754235
# std        0.462463
# min        0.788000
# 25%        1.410000
# 50%        1.780000
# 75%        2.170000
# max        3.030000
# Name: planet_radius_earth, dtype: float64

# %% [markdown]
# The distribution of planet radius shows the range of planet sizes, where most planets cluster close to the size or less than double of the Earth, 1.0 -2.0. A smaller number of planets have larger radii, greater than twice the size of the Earth. The overall distribution suggests most common habitable planets are Earth-sized and super-Earth sized.

# %% [markdown]
# ### Planet Mass

# %%
# Call Univariate method for Planet Mass
univariate_analysis(merged_planets, 'planet_mass_earth')
# Out:
# count    324.000000
# mean       6.319910
# std        8.265157
# min        0.388000
# 25%        2.540000
# 50%        4.120000
# 75%        5.650000
# max       36.000000
# Name: planet_mass_earth, dtype: float64

# %% [markdown]
# The distribution of planet mass is right-skewed, where most planets are 1 to 6 times the size of the Earth. A small number of planets are significantly larger, and may be outliers compared to the majority of the dataset. Overall, the dataset contains mostly lower-massed planets that are more similar to Earth or super-Earth planets.

# %% [markdown]
# ### Orbital Period

# %%
# Call Univariate method for Orbital Period
univariate_analysis(merged_planets, 'orbital_period_days')
# Out:
# count    324.000000
# mean     101.525451
# std       89.631206
# min        4.049219
# 25%       32.939623
# 50%       63.336270
# 75%      140.252400
# max      384.843000
# Name: orbital_period_days, dtype: float64

# %% [markdown]
# The distribution of orbital periods is heavily right skewed, with most planets orbiting the host star in less that approximately 125 days. The histogram suggests that shorter orbital periods are more common in the dataset, where a small number of planets have longer orbital periods up to approximately 400 days. The difference in the periods may suggest the planets distance from their host star however, all fall in within a perceivable range of Earth days, and Earth orbital period of 365 days.

# %% [markdown]
# ### Surface Temperature

# %%
# Call Univariate method for Surface Temperature
univariate_analysis(merged_planets, 'surface_temperature_K')
# Out:
# count    324.000000
# mean     273.654971
# std       32.611130
# min      198.928456
# 25%      251.843755
# 50%      278.800421
# 75%      297.996788
# max      325.367512
# Name: surface_temperature_K, dtype: float64

# %% [markdown]
# The distribution of surface temperature ranges approximately between 200 to 325 Kelvin. A significantly peak occurs approximately at 280 Kelvin, which is near Earth's average surface temperature of 288 Kelvin. Surface temperature seems to be more evenly distributed and have less extreme values, which suggests that temperature may be a top characteristic associated with the Earth Similarity Index (ESI).

# %% [markdown]
# ## Bi-variate Analysis

# %% [markdown]
# ### Planet Radius vs Earth Similarity Index (ESI)

# %%
# Create Bi-variate Method
def bivariate_analysis(df, x_col, y_col):
    plt.figure(figsize=(10, 6))
    sns.regplot(data=df, x=x_col, y=y_col)
    plt.title(f'{y_col} vs {x_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

    correlation = df[x_col].corr(df[y_col])
    print()
    print(f'Correlation between {x_col} and {y_col}: {correlation:.2f}')
    if correlation > 0:
        print('Positive correlation')
    else:
        print('Negative correlation')

# %%
# Call Bi-variate method for Earth Similarity Index vs. Planet Radius
bivariate_analysis(merged_planets, 'planet_radius_earth', 'earth_similarity_index')
# Out:
# Correlation between planet_radius_earth and earth_similarity_index: -0.44
# Negative correlation

# %% [markdown]
# The regression plot indicates a negative relationship between planet radius and the Earth Similarity Index (ESI). As the planet's radii increase, ESI begins to slightly decrease, suggesting planets closer to Earth's size are more Earth-like. While there is some variability present, the downward trend may suggest radius is a factor in habitability.

# %% [markdown]
# ### Planet Mass vs Earth Similarity Index (ESI)

# %%
# Call Bi-variate method for Earth Similarity Index vs. Planet Mass
bivariate_analysis(merged_planets, 'planet_mass_earth', 'earth_similarity_index')
# Out:
# Correlation between planet_mass_earth and earth_similarity_index: -0.05
# Negative correlation

# %% [markdown]
# The regression plot shows a weak negative relationship between planet mass and ESI. The slight decrease, yet nearly flat regression line, and significant scatter among planet mass indicate mass is not a strong characteristic predicting Earth similarity. There are a few large massed planets as outliers, with a couple showing a relatively high ESI, further suggesting mass may not contribute to habitability of the planet.

# %% [markdown]
# ### Planet Orbital Period vs Earth Similarity Index

# %%
# Call Bi-variate method for Earth Similarity Index vs. Orbital Period
bivariate_analysis(merged_planets, 'orbital_period_days', 'earth_similarity_index')
# Out:
# Correlation between orbital_period_days and earth_similarity_index: -0.21
# Negative correlation

# %% [markdown]
# The regression plot shows a slightly negative relationship between orbital period and ESI, as orbital period increases ESI tends to decrease. The data points however, are scattered around the regression line and are widely dispersed. The plot indicates that orbital period is not a strong characteristic predicting ESI or habitability, even though shorter orbital periods are more commonly associated with higher ESI, there is significant variability.

# %% [markdown]
# ### Surface Temperature vs Earth Similarity Index (ESI)

# %%
# Call Bi-variate method for Earth Similarity Index vs. Surface Temperature
bivariate_analysis(merged_planets, 'surface_temperature_K', 'earth_similarity_index')
# Out:
# Correlation between surface_temperature_K and earth_similarity_index: 0.57
# Positive correlation

# %% [markdown]
# The regression plot shows a positive relationship between surface temperature and ESI. Planets with relatively higher temperatures tend to have higher ESI values. There is some variability present, but the upward trend suggests that temperature is an important characteristics predicting similarity to Earth and habitability. A note to consider, the trend is within the temperature ranges present in the dataset, and not necessarily an upward trend beyond the present temperatures.

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ### Correlation Matrix

# %%
# Correlation between all numerical features
correlation_matrix = merged_planets.select_dtypes(include=['float64', 'int64']).corr()
correlation_matrix
# Out:
#                            star_temperature_K  stellar_radius_solar  \
# star_temperature_K                   1.000000              0.730602
# stellar_radius_solar                 0.730602              1.000000
# stellar_mass_solar_masses            0.740840              0.672059
# stellar_metallicity                 -0.034895              0.043158
# planet_mass_earth                    0.262386              0.135135
# planet_radius_earth                  0.343286              0.322593
# stellar_flux_earth                   0.249510              0.209581
# surface_temperature_K                0.214586              0.190292
# orbital_period_days                  0.639760              0.561736
# distance_light_years                 0.517983              0.603031
# planet_age_gigayears                 0.221819              0.099276
# earth_similarity_index              -0.089342             -0.103290
#
#                            stellar_mass_solar_masses  stellar_metallicity  \
# ...

# %% [markdown]
# The strongest positive correlation with ESI is surface temperature (approximately 0.57), suggesting temperatures around Earth's average temperature tend to have higher ESI values and strongly contributes to habitability. The next strongest positive correlation is stellar flux (approximately 0.47), indicating that the amount of energy the host star emits to the planet may majorly contribute to the planet's habitability. The strongest negative correlation is planet radius (approximately -0.44), suggesting that larger planets tend to have lower ESI values. Most of the stellar characteristics, including stellar temperature, radius, mass, and metallicity, show weak correlations with ESI. Stellar flux is the only star characteristic that indicates a strong influence on  ESI and habitability.

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# The correlation heatmap shows and confirms meaningful relationships among the features. The heatmap confirms ESI shows the strongest positive correlations with surface temperature (0.57) and stellar flux (0.47), suggesting these features are likely important influential predictors of planetary habitability. Additionally, stellar flux and surface temperature have a strong positive correlation (0.96), indicating planets that receive greater stellar energy have higher surface temperatures, contributing to the habitability of the planet and ESI values. ESI also shows negative correlation with planet radius (-0.44), suggesting larger planets are less likely to be Earth-like, where planet mass shows only a weak relationship with ESI (-0.05). Orbital period shows a small, weak negative correlation (-0.21).

# %% [markdown]
# ### Correlation Bar Chart (ESI)

# %%
esi_correlation = correlation_matrix['earth_similarity_index'].drop('earth_similarity_index')
esi_correlation.sort_values(ascending=False).plot(kind='barh', figsize=(8, 6))
plt.xlabel('Correlation with Earth Similarity Index')
plt.ylabel('Features')
plt.title('Correlation of Features with Earth Similarity Index')
plt.show()

# %% [markdown]
# The correlation bar chart ranks each feature by the relationships with ESI. The findings support the observations and the rest of the bi-variate analysis, and confirms insight into which features are strongly associated with ESI and habitability. The features with the strongest correlations will be most useful for predictive machine modeling.

# %% [markdown]
# ## EDA Findings
# The exploratory data analysis identified important relationships associated with the Earth Similarity Index (ESI). The univariate analysis showed most of the planets in the dataset have moderate ESI values, where planet mass and orbital period had right-skewed distributions. Surface temperature was distributed mainly between 250 to 320 Kelvin, corresponding to habitable temperature ranges, including Earth's average surface temperature of 288 Kelvin.
#
# The bi-variate and correlation analysis identified that surface temperature (0.57) and stellar flux (0.47) have the strongest positive relationship with ESI, suggesting that energy the planet receives from its host star and temperature are strongly associated with planet habitability. Planet radius showed a strong negative relationship (-0.44) with ESI, indicating Earth that larger planets tend to be less Earth-like. Additionally, stellar flux and temperature were strongly correlated (0.96), showing a strong relationship between stellar energy emission and planetary temperature.
#
# In summary, the EDA results suggest that planet size, stellar flux, and surface temperature are among the most influential characteristics related to Earth similarity and contributing to planet habitability. The findings provide features for selection and predictive machine modeling.

# %% [markdown]
# # Feature Selection and Model Preparation
# The Earth Similarity Index (ESI) is the selected target variable for prediction. All the numerical features will be used as predictors because they all represent planetary and stellar characteristics related to habitability. The correlation analysis showed that surface temperature, stellar flux, and planet radius have the strongest relationships with ESI, where the remaining features will be evaluated by the machine learning model.

# %% [markdown]
# ### Define Features

# %%
# Define features (x) and target variable (y)

x = merged_planets.select_dtypes(include=['float64', 'int64']).drop(columns=['earth_similarity_index'])
y = merged_planets['earth_similarity_index']

print("Features (x) shape:", x.shape)
print("Target variable (y) shape:", y.shape)
# Out:
# Features (x) shape: (324, 11)
# Target variable (y) shape: (324,)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Training set shape (x_train):", x_train.shape)
print("Testing set shape (x_test):", x_test.shape)
print("Training set shape (y_train):", y_train.shape)
print("Testing set shape (y_test):", y_test.shape)
# Out:
# Training set shape (x_train): (259, 11)
# Testing set shape (x_test): (65, 11)
# Training set shape (y_train): (259,)
# Testing set shape (y_test): (65,)

# %% [markdown]
# ### Feature Scaling
# Feature scaling is utilized to standardize the predictor variables, and ensure features measured on different scales are equally contributed.

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

print("Scaled training set shape (x_train_scaled):", x_train_scaled.shape)
print("Scaled testing set shape (x_test_scaled):", x_test_scaled.shape)
# Out:
# Scaled training set shape (x_train_scaled): (259, 11)
# Scaled testing set shape (x_test_scaled): (65, 11)

# %% [markdown]
# ### Linear Regression Model
# The model was selected as a baseline for predicting Earth Similarity Index(ESI). The model estimates relationships betweens the predictor variables and ESI by a linear fitting to the data. This model simplicity will prove the baseline for comparison with more complex models.

# %%
# Create, train, and predict with Linear Regression model
linear_model = LinearRegression()
linear_model.fit(x_train_scaled, y_train)

y_pred_linear = linear_model.predict(x_test_scaled)

# %%
# Model Evaluation for Linear Regression
mean_absolute_error_linear = mean_absolute_error(y_test, y_pred_linear)
root_mean_squared_error_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
r2_score_linear = r2_score(y_test, y_pred_linear)

print(f"Mean Absolute Error: {mean_absolute_error_linear:.5f}")
print(f"Root Mean Squared Error: {root_mean_squared_error_linear:.5f}")
print(f"Testing R^2 Score: {r2_score_linear:.5f}")

# Check for overfitting by comparing training and testing performance
y_train_pred_linear = linear_model.predict(x_train_scaled)
train_r2 = r2_score(y_train, y_train_pred_linear)
print(f"Training R^2 Score: {train_r2:.5f}")
# Out:
# Mean Absolute Error: 0.03304
# Root Mean Squared Error: 0.04485
# Testing R^2 Score: 0.75319
# Training R^2 Score: 0.80561

# %% [markdown]
# The Linear Regression model resulted in a R squared score of 0.75319, indicating approximately 75.3% of ESI variation can be interpreted by predictor variables.The model produced low mean absolute error and root mean squared error values suggesting the predictions are relatively accurate and generalizes unseen data reasonable. The comparison of the training and testing R squared scores show minimal over-fitting.

# %% [markdown]
# ## Random Forest Regressor Model
# The model was selected to capture more complex and nonlinear relationships between the predictor variables and ESI. The model uses multiple decision trees to improve predictions and reduce over-fitting. The model results will be compared to the Linear Regression model.

# %%
# Create, train, and predict with Random Forest Regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

y_pred_rf = rf_model.predict(x_test)

# %%
# Model Evaluation for Random Forest Regressor
mean_absolute_error_rf = mean_absolute_error(y_test, y_pred_rf)
root_mean_squared_error_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_score_rf = r2_score(y_test, y_pred_rf)

print(f"Mean Absolute Error: {mean_absolute_error_rf:.5f}")
print(f"Root Mean Squared Error: {root_mean_squared_error_rf:.5f}")
print(f"Testing R^2 Score: {r2_score_rf:.5f}")

# Check for overfitting by comparing training and testing performance
y_train_pred_rf = rf_model.predict(x_train)
train_r2 = r2_score(y_train, y_train_pred_rf)
print(f"Training R^2 Score: {train_r2:.5f}")
# Out:
# Mean Absolute Error: 0.00385
# Root Mean Squared Error: 0.01071
# Testing R^2 Score: 0.98592
# Training R^2 Score: 0.99434

# %% [markdown]
# The Random Forest Regressor greatly outperformed the Linear Regression model across all metrics. The model resulted in a R squared scored of 0.98592, indicating approximately 98.6% of ESI variation can be interpreted by the predictor variables. The low mean absolute error and root squared error values show high accurate predictions. The small difference between the training and testing R squared scores suggest very minimal over-fitting and a strong generalization performance.

# %% [markdown]
# ### Model Comparison Findings
# The Linear Regression model served as a baseline comparison and achieved a testing R squared score of 0.75319. The model attained general relationships between the predictor variables and ESI, however its performance was much lower than the Random Forest Regressor. The Random Forest Regressor achieved a testing R squared score of 0.98592 with significantly lower error values. The small difference between the training nd testing score indicates a strong generalization performance with minimal over-fitting.
#
# Based on the results of the two models, the Random Forest Regressor was selected as the final model because it resulted in much more accurate predictions of The Earth Similarity Index and attained complex relationships between stellar and planetary characteristics.

# %% [markdown]
# ## Feature Importance Analysis
# Feature importance was evaluated by the Random Forest Regressor and the analysis will identify which stellar and planetary characteristics contribute most to predicting the Earth Similarity Index (ESI). The features with a higher importance score, have a greater influence on the model's predictions and will provide understanding into which characteristics are most associated with ESI and planet habitability.

# %%
# Feature importance from Random Forest model
feature_importances = rf_model.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': x.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Feature importance to csv
feature_importance_df.to_csv('data/feature_importance.csv', index=False)

feature_importance_df
# Out:
#                       Feature  Importance
# 5         planet_radius_earth    0.403341
# 6          stellar_flux_earth    0.317053
# 7       surface_temperature_K    0.228682
# 4           planet_mass_earth    0.023482
# 9        distance_light_years    0.007007
# 8         orbital_period_days    0.005915
# 0          star_temperature_K    0.004737
# 10       planet_age_gigayears    0.004293
# 1        stellar_radius_solar    0.002382
# 3         stellar_metallicity    0.001911
# 2   stellar_mass_solar_masses    0.001198

# %%
# Feature importance plot
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Feature Importance - Random Forest')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### Feature Importance Findings
# The feature importance analysis identified planet radius, stellar flux, and surface temperature as the strongest characteristics associated with Earth Similarity Index (ESI). Planet radius had the highest score of importance of 0.403341, followed by stellar flux of 0.317053, and surface temperature of 0.228682. Altogether, the three characteristics accounted for approximately 95% of the importance for the model's prediction.
#
# The findings are consistent with the correlation analysis, which showed a strong negative correlation between planet radius and ESI, and positive correlations with stellar flux and surface temperature. The final result suggest that planet radius (size), stellar flux (energy), and surface temperature are the characteristics that are most strongly associated with exoplanet habitability as measure by the Earth Similarity Index (ESI).

# %% [markdown]
# ## Conclusion
# This study examined which planetary and stellar characteristics are most strongly associated with exoplanet habitability as measured by the Earth Similarity Index (ESI). Exploratory Data Analysis helped identify meaningful relationships ESI and several variables, specifically planet radius, stellar flux and surface temperature.
#
# The two machine learning models, the Linear Regression model and the Random Forest Regressor were evaluated to predict ESI. The Linear Regression model was a useful baseline producing a testing R squared score of 0.75319, while the Random Forest Regressor achieved significantly better performance of a testing R squared score of 0.98592 with very low prediction error. The overall results indicate that the Random Forest Regressor is highly effective attaining relationships between stellar and planetary characteristics to predict ESI.
#
# The feature importance analysis identified that planet radius, stellar flux, and surface temperature were the most influential predictor of ESI. The results indicate that planet radius, stellar flux, and surface temperature are the characteristics most strongly associated with exoplanet habitability as measure by the Earth Similarity Index (ESI).
#
# In conclusion, the findings demonstrate that machine learning can model the Earth Similarity Index effectively, and identify key characteristics that contribute to exoplanet habitability.

# %% [markdown]
# ## Future Work
# Future research could incorporate additional exoplanet and stellar datasets that include more characteristics, such as atmospheric characteristics. More advanced machine learning techniques, as well as classification approaches combined with regression models could further improve habitability predictions and provide deeper insights into potentially Earth-like worlds. As technology and data advances, future exoplanet studies and research to develop machine learning models could potentially advance the search for life beyond Earth.
